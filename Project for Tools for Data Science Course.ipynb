# %%
#Cell 1 - Headings

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %%
#Cell 2 - Font

# %% [markdown]
# **Funmi Olugbode**
#
# Engineer

# %%
#Cell 3 - Font

# %% [markdown]
# *I am interested in data science because I want to prepare for the jobs of the future and solve societial issues.*

# %%
#Cell 4 - Headings

# %% [markdown]
# ### Executing a mathematical function in Cell 5, displaying the code and output.

# %%
#Cell 5 - Mathematical Function

# %%
x=4
y=6
a=10*(y-x)/x
print(int(a))
# Out:
# 5

# %%
# Cell 6 - Markdown Basic

# %% [markdown]
# HORIZONTAL RULE
# * * *
#
# *****
#
# -----
#
# BULLETEED LIST
# * Apple
# * Banana
# * Cantaloupe
#
# NUMBERED LIST
# 1. Apple
# 2. Banana
# 3. Cantaloupe
#
#
# HYPERLINKS
#
# [Click_Here](https://www.google.com)
#
# BLOCKED QUOTES
#
# > ## Blockquoted header
# >
# > This will be blocked.
# >
# > This is a second paragraph within the blockquoted text.
#
# STRIKETHROUGH
#
# ~~Apple~~
# ~~Banana~~
# ~~Cantaloupe~~
